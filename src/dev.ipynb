# %%
from openweatherclient import OpenWeatherClient



client = OpenWeatherClient()

weather = client.get_weather_by_location(
    city= "bengaluru"
)

import json
with open("weather.json", "w") as f:
    json.dump(weather, f, indent=4)
# Out:
# INFO:root:Cache hit for location: bengaluru
# INFO:root:Cache hit for weather: bengaluru
# INFO:root:Cache expired: 696
# December 15, 2025 08:34 PM IST
# December 15, 2025 08:41 PM IST

# %%
from datetime import datetime, timedelta, timezone
datetime.now(timezone.utc).timestamp()
# Out:
# 1765804503.807751

# %%
from datetime import datetime, timedelta, timezone

def local_time_to_unix(
    local_time_str: str,
    offset_seconds: int = 19800,
    time_format: str = "%B %d, %Y %I:%M %p"
) -> int:
    """
    Convert formatted local time string back to UNIX timestamp.

    Example input:
      local_time_str = "December 15, 2025 02:20 PM IST"
      offset_seconds = 19800
    """
    local_time_str = local_time_str.strip(" IST")
    print(local_time_str)
    # Create timezone from offset
    tz = timezone(timedelta(seconds=offset_seconds))

    # Parse string into naive datetime
    naive_dt = datetime.strptime(local_time_str, time_format)

    # Attach timezone
    aware_dt = naive_dt.replace(tzinfo=tz)

    # Convert to UNIX timestamp
    return int(aware_dt.timestamp())

local_time = "December 15, 2025 06:49 PM IST"
offset = 19800  # IST

diff = abs(local_time_to_unix(local_time) - int(datetime.now(timezone.utc).timestamp()))
print(diff)
# Out:
# December 15, 2025 06:49 PM
# 6645

# %%
from datetime import datetime, timedelta, timezone

def unix_to_local_time(timestamp: int, offset_seconds: int) -> datetime:
    tz = timezone(timedelta(seconds=offset_seconds))
    return datetime.fromtimestamp(timestamp, tz=tz)


# Example
timestamp = 1765804740
offset = 19800

local_time = unix_to_local_time(timestamp, offset)
print(local_time.strftime("%B %d, %Y %I:%M %p"))
# Out:
# December 15, 2025 06:49 PM

# %%
from datetime import datetime, UTC
import pytz

def unix_to_ist(timestamp: int) -> str:
    """
    Convert UNIX timestamp to IST local time.
    Output format: Month DD, YYYY HH:MM AM/PM IST
    """
    ist = pytz.timezone("Asia/Kolkata")

    dt_utc = datetime.fromtimestamp(timestamp, UTC)
    dt_ist = dt_utc.replace(tzinfo=pytz.utc).astimezone(ist)

    return dt_ist.strftime("%B %d, %Y %I:%M %p IST")


# Example
timestamp = 1765799406
print(unix_to_ist(timestamp))
# Out:
# December 15, 2025 05:20 PM IST

# %%
from datetime import datetime, timezone
ts = int('1765760625')

# if you encounter a "year is out of range" error the timestamp
# may be in milliseconds, try `ts /= 1000` in that case
print(datetime.fromtimestamp(ts, timezone.utc).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 6
#       2 ts = int('1765760625')
#       4 # if you encounter a "year is out of range" error the timestamp
#       5 # may be in milliseconds, try `ts /= 1000` in that case
# ----> 6 print(datetime.fromtimestamp(ts, timezone.ist).strftime('%Y-%m-%d %H:%M:%S'))
#
# AttributeError: type object 'datetime.timezone' has no attribute 'ist'

# %%
from datetime import timezone
import datetime

# Getting the current date and time
dt = datetime.datetime.now(timezone.utc)

a = dt.replace(tzinfo=timezone.utc)
b = a.timestamp()
print(dt)
print(a)
print(b)
# Out:
# 2025-12-15 12:28:44.968288+00:00
# 2025-12-15 12:28:44.968288+00:00
# 1765801724.968288

# %%
from openweatherclient import OpenWeatherGeoClient

client = OpenWeatherGeoClient()
city = "bengaluru"

response = client.get_coordinates(city=city)
response
# Out:
# INFO:root:Cache hit for location: bengaluru
# ({'lon': 77.6033, 'lat': 12.9762},
#  {'location_query': 'bengaluru',
#   'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lon': 77.6033, 'lat': 12.9762},
#   'dt': 1765798833,
#   'id': 1277333,
#   'main': {'temp': 297.95,
#    'feels_like': 297.35,
#    'temp_min': 297.95,
#    'temp_max': 298.05,
#    'pressure': 1013,
#    'humidity': 33,
#    'sea_level': 1013,
#    'grnd_level': 915},
#   'name': 'Bengaluru',
#   'sys': {'type': 1,
#    'id': 9205,
#    'country': 'IN',
#    'sunrise': 1765760625,
#    'sunset': 1765801542},
#   'timezone': 19800,
#   'visibility': 6000,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'wind': {'speed': 3.09, 'deg': 90}})

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.15.5-cp313-cp313-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Using cached dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.15.5-cp313-cp313-win_amd64.whl (962 kB)
#    ---------------------------------------- 0.0/962.6 kB ? eta -:--:--
#    ---------------------------------------- 962.6/962.6 kB 7.8 MB/s  0:00:00
# Using cached dnspython-2.8.0-py3-none-any.whl (331 kB)
# Installing collected packages: dnspython, pymongo
#
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    ---------------------------------------- 2/2 [pymongo]
#
# Successfully installed dnspython-2.8.0 pymongo-4.15.5

# %% [markdown]
# ## Decision Making node

# %%
from workflow import decision_making_node, AgentState
from langchain_core.messages import AIMessage, SystemMessage, HumanMessage, ToolMessage
state = {"messages": [HumanMessage(content="What’s the weather in Bengaluru right now?")]}
state = AgentState(**state)

response = decision_making_node(state)

# %%
response
# Out:
# {'action': 'weather',
#  'messages': [AIMessage(content='null', additional_kwargs={}, response_metadata={})]}

# %%
message = "Hello ClimaDoc"
state = {"messages": [HumanMessage(content=message)]}
state = AgentState(**state)

response = decision_making_node(state)
response
# Out:
# {'action': 'direct',
#  'messages': [AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={})]}

# %% [markdown]
# ## Planning node

# %%
from workflow import planning_node, AgentState, HumanMessage,  agent_node, tools_node,judge_node


message = "What’s the weather in Bengaluru right now?"
state = {"messages": [HumanMessage(content=message)]}
state = AgentState(**state)

response = planning_node(state)
print(response)
agent_response = agent_node(response)
print(agent_response)
tool_response = tools_node(agent_response)
print(tool_response)
ans = agent_node(tool_response)
print(ans)
judge_ans = judge_node(ans)
judge_ans
# Out:
# {'messages': [AIMessage(content='1. **Step 1**: Get the current weather information for Bengaluru. - Use tool: get_weather_info_by_location', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--c6acb47e-4330-40b5-865e-e5e4c6608933-0', usage_metadata={'input_tokens': 547, 'output_tokens': 29, 'total_tokens': 576, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1}
# {'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--9b653ddc-ea86-43a7-af58-05ac4bbed224-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': '5e3a726f-5826-4c66-8aa1-da1f233f975b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 536, 'output_tokens': 12, 'total_tokens': 548, 'input_token_details': {'cache_read': 0}})]}
# INFO:root:Cache hit for location: Bengaluru
# INFO:root:Cache hit for weather: Bengaluru
# INFO:root:Cache hit for weather: Bengaluru. Cached time difference is 867 seconds
# December 15, 2025 10:21 PM IST
# {'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--9b653ddc-ea86-43a7-af58-05ac4bbed224-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': '5e3a726f-5826-4c66-8aa1-da1f233f975b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 536, 'output_tokens': 12, 'total_tokens': 548, 'input_token_details': {'cache_read': 0}}), ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6033, "lat": 12.9762}, "weather": [{"id": 800, "main": "Clear", "description": "clear sky", "icon": "01n"}], "base": "stations", "main": {"temp": 17.77, "feels_like": 17.51, "temp_min": 17.5, "temp_max": 17.84, "pressure": 1016, "humidity": 73, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 10}, "dt": "December 15, 2025 10:21 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='5e3a726f-5826-4c66-8aa1-da1f233f975b')]}
# {'messages': [AIMessage(content='The weather in Bengaluru is clear sky with a temperature of 17.77 degrees Celsius, feels like 17.51 degrees Celsius, humidity of 73%, and wind speed of 5.14 m/s.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--466a207f-f051-4880-9090-2a4f86996f34-0', usage_metadata={'input_tokens': 669, 'output_tokens': 51, 'total_tokens': 720, 'input_token_details': {'cache_read': 0}})]}
# {'is_good_answer': True, 'num_feedback_requests': 1}

# %% [markdown]
# ## Test the full workflow

# %%
from workflow import run_climadoc_workflow

query = "What’s the weather in Bengaluru right now?"
result = run_climadoc_workflow(query)
result
# Out:
# [values] {'messages': [HumanMessage(content='What’s the weather in Bengaluru right now?', additional_kwargs={}, response_metadata={})]}
# Decision making node: {'action': 'weather'}
# [updates] {'decision_making': {'action': 'weather'}}
# [values] {'action': 'weather', 'messages': [HumanMessage(content='What’s the weather in Bengaluru right now?', additional_kwargs={}, response_metadata={})]}
# Planning node output: content='1. **Step 1**: Get the current weather information for Bengaluru. - Use tool: get_weather_info_by_location' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--fdd26937-97d1-441c-a954-f0dc6f58ddfd-0' usage_metadata={'input_tokens': 547, 'output_tokens': 29, 'total_tokens': 576, 'input_token_details': {'cache_read': 0}}
# [updates] {'planning': {'messages': [AIMessage(content='1. **Step 1**: Get the current weather information for Bengaluru. - Use tool: get_weather_info_by_location', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--fdd26937-97d1-441c-a954-f0dc6f58ddfd-0', usage_metadata={'input_tokens': 547, 'output_tokens': 29, 'total_tokens': 576, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1}}
# [values] {'action': 'weather', 'messages': [AIMessage(content='1. **Step 1**: Get the current weather information for Bengaluru. - Use tool: get_weather_info_by_location', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--fdd26937-97d1-441c-a954-f0dc6f58ddfd-0', usage_metadata={'input_tokens': 547, 'output_tokens': 29, 'total_tokens': 576, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1}
# Agent node output: content='' additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--8f15f399-20d9-44f9-9016-823d938966f6-0' tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': '28d666bc-f5ef-4d61-85c3-a85ae8fdc537', 'type': 'tool_call'}] usage_metadata={'input_tokens': 536, 'output_tokens': 12, 'total_tokens': 548, 'input_token_details': {'cache_read': 0}}
# [updates] {'agent': {'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--8f15f399-20d9-44f9-9016-823d938966f6-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': '28d666bc-f5ef-4d61-85c3-a85ae8fdc537', 'type': 'tool_call'}], usage_metadata={'input_tokens': 536, 'output_tokens': 12, 'total_tokens': 548, 'input_token_details': {'cache_read': 0}})]}}
# [values] {'action': 'weather', 'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--8f15f399-20d9-44f9-9016-823d938966f6-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': '28d666bc-f5ef-4d61-85c3-a85ae8fdc537', 'type': 'tool_call'}], usage_metadata={'input_tokens': 536, 'output_tokens': 12, 'total_tokens': 548, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1}
# INFO:root:Cache hit for location: Bengaluru
# INFO:root:Cache hit for weather: Bengaluru
# INFO:root:Cache expired: 2230
# December 15, 2025 10:21 PM IST
# December 15, 2025 10:50 PM IST
# Tools node output: [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6033, "lat": 12.9762}, "weather": [{"id": 800, "main": "Clear", "description": "clear sky", "icon": "01n"}], "base": "stations", "main": {"temp": 17.06, "feels_like": 16.86, "temp_min": 16.8, "temp_max": 17.84, "pressure": 1016, "humidity": 78, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 10}, "dt": "December 15, 2025 10:50 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='28d666bc-f5ef-4d61-85c3-a85ae8fdc537')]
# [updates] {'tools': {'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--8f15f399-20d9-44f9-9016-823d938966f6-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': '28d666bc-f5ef-4d61-85c3-a85ae8fdc537', 'type': 'tool_call'}], usage_metadata={'input_tokens': 536, 'output_tokens': 12, 'total_tokens': 548, 'input_token_details': {'cache_read': 0}}), ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6033, "lat": 12.9762}, "weather": [{"id": 800, "main": "Clear", "description": "clear sky", "icon": "01n"}], "base": "stations", "main": {"temp": 17.06, "feels_like": 16.86, "temp_min": 16.8, "temp_max": 17.84, "pressure": 1016, "humidity": 78, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 10}, "dt": "December 15, 2025 10:50 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='28d666bc-f5ef-4d61-85c3-a85ae8fdc537')]}}
# [values] {'action': 'weather', 'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--8f15f399-20d9-44f9-9016-823d938966f6-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': '28d666bc-f5ef-4d61-85c3-a85ae8fdc537', 'type': 'tool_call'}], usage_metadata={'input_tokens': 536, 'output_tokens': 12, 'total_tokens': 548, 'input_token_details': {'cache_read': 0}}), ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6033, "lat": 12.9762}, "weather": [{"id": 800, "main": "Clear", "description": "clear sky", "icon": "01n"}], "base": "stations", "main": {"temp": 17.06, "feels_like": 16.86, "temp_min": 16.8, "temp_max": 17.84, "pressure": 1016, "humidity": 78, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 10}, "dt": "December 15, 2025 10:50 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='28d666bc-f5ef-4d61-85c3-a85ae8fdc537')], 'num_planning_cycles': 1}
# Agent node output: content='The weather in Bengaluru is clear sky. The temperature is 17.06 degrees Celsius, but it feels like 16.86 degrees Celsius. The humidity is 78%. The wind speed is 5.14 m/s from the east.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--00ae87ad-cf9d-4e8e-a49d-1812b4dfb66d-0' usage_metadata={'input_tokens': 669, 'output_tokens': 57, 'total_tokens': 726, 'input_token_details': {'cache_read': 0}}
# [updates] {'agent': {'messages': [AIMessage(content='The weather in Bengaluru is clear sky. The temperature is 17.06 degrees Celsius, but it feels like 16.86 degrees Celsius. The humidity is 78%. The wind speed is 5.14 m/s from the east.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--00ae87ad-cf9d-4e8e-a49d-1812b4dfb66d-0', usage_metadata={'input_tokens': 669, 'output_tokens': 57, 'total_tokens': 726, 'input_token_details': {'cache_read': 0}})]}}
# [values] {'action': 'weather', 'messages': [AIMessage(content='The weather in Bengaluru is clear sky. The temperature is 17.06 degrees Celsius, but it feels like 16.86 degrees Celsius. The humidity is 78%. The wind speed is 5.14 m/s from the east.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--00ae87ad-cf9d-4e8e-a49d-1812b4dfb66d-0', usage_metadata={'input_tokens': 669, 'output_tokens': 57, 'total_tokens': 726, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1}
# [updates] {'judge': {'is_good_answer': True}}
# [values] {'action': 'weather', 'messages': [AIMessage(content='The weather in Bengaluru is clear sky. The temperature is 17.06 degrees Celsius, but it feels like 16.86 degrees Celsius. The humidity is 78%. The wind speed is 5.14 m/s from the east.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--00ae87ad-cf9d-4e8e-a49d-1812b4dfb66d-0', usage_metadata={'input_tokens': 669, 'output_tokens': 57, 'total_tokens': 726, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1, 'is_good_answer': True}
# {'action': 'weather',
#  'messages': [AIMessage(content='The weather in Bengaluru is clear sky. The temperature is 17.06 degrees Celsius, but it feels like 16.86 degrees Celsius. The humidity is 78%. The wind speed is 5.14 m/s from the east.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--00ae87ad-cf9d-4e8e-a49d-1812b4dfb66d-0', usage_metadata={'input_tokens': 669, 'output_tokens': 57, 'total_tokens': 726, 'input_token_details': {'cache_read': 0}})],
#  'num_planning_cycles': 1,
#  'is_good_answer': True}

# %%
from workflow import run_climadoc_workflow
query = "Will it rain in Bengaluru today? "
result = run_climadoc_workflow(query)
result
# Out:
# [values] {'query': [HumanMessage(content='Will it rain in Bengaluru today?', additional_kwargs={}, response_metadata={})], 'messages': [HumanMessage(content='Will it rain in Bengaluru today?', additional_kwargs={}, response_metadata={})]}
# Decision making node: {'action': 'weather'}
# [updates] {'decision_making': {'action': 'weather'}}
# [values] {'query': [HumanMessage(content='Will it rain in Bengaluru today?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [HumanMessage(content='Will it rain in Bengaluru today?', additional_kwargs={}, response_metadata={})]}
# Planning node output: content='1. **Step 1**: Get weather information for Bengaluru - Use tool: get_weather_info_by_location' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--aeb84596-8d63-4ceb-ba37-5c812fb487a9-0' usage_metadata={'input_tokens': 544, 'output_tokens': 26, 'total_tokens': 570, 'input_token_details': {'cache_read': 0}}
# [updates] {'planning': {'messages': [AIMessage(content='1. **Step 1**: Get weather information for Bengaluru - Use tool: get_weather_info_by_location', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--aeb84596-8d63-4ceb-ba37-5c812fb487a9-0', usage_metadata={'input_tokens': 544, 'output_tokens': 26, 'total_tokens': 570, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1}}
# [values] {'query': [HumanMessage(content='Will it rain in Bengaluru today?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content='1. **Step 1**: Get weather information for Bengaluru - Use tool: get_weather_info_by_location', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--aeb84596-8d63-4ceb-ba37-5c812fb487a9-0', usage_metadata={'input_tokens': 544, 'output_tokens': 26, 'total_tokens': 570, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1}
# Agent node output: content='' additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--54dea085-81f2-4870-ab2f-2e8766482afa-0' tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': 'b4fba856-8b10-4630-89e7-1aef33c527ce', 'type': 'tool_call'}] usage_metadata={'input_tokens': 533, 'output_tokens': 12, 'total_tokens': 545, 'input_token_details': {'cache_read': 0}}
# [updates] {'agent': {'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--54dea085-81f2-4870-ab2f-2e8766482afa-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': 'b4fba856-8b10-4630-89e7-1aef33c527ce', 'type': 'tool_call'}], usage_metadata={'input_tokens': 533, 'output_tokens': 12, 'total_tokens': 545, 'input_token_details': {'cache_read': 0}})]}}
# [values] {'query': [HumanMessage(content='Will it rain in Bengaluru today?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--54dea085-81f2-4870-ab2f-2e8766482afa-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': 'b4fba856-8b10-4630-89e7-1aef33c527ce', 'type': 'tool_call'}], usage_metadata={'input_tokens': 533, 'output_tokens': 12, 'total_tokens': 545, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1}
# INFO:root:Cache hit for location: Bengaluru
# INFO:root:Cache hit for weather: Bengaluru
# INFO:root:Cache hit for weather: Bengaluru. Cached time difference is 1038 seconds
# December 15, 2025 11:14 PM IST
# [updates] {'tools': {'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--54dea085-81f2-4870-ab2f-2e8766482afa-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': 'b4fba856-8b10-4630-89e7-1aef33c527ce', 'type': 'tool_call'}], usage_metadata={'input_tokens': 533, 'output_tokens': 12, 'total_tokens': 545, 'input_token_details': {'cache_read': 0}}), ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='b4fba856-8b10-4630-89e7-1aef33c527ce')], 'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='b4fba856-8b10-4630-89e7-1aef33c527ce')]}}
# [values] {'query': [HumanMessage(content='Will it rain in Bengaluru today?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--54dea085-81f2-4870-ab2f-2e8766482afa-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': 'b4fba856-8b10-4630-89e7-1aef33c527ce', 'type': 'tool_call'}], usage_metadata={'input_tokens': 533, 'output_tokens': 12, 'total_tokens': 545, 'input_token_details': {'cache_read': 0}}), ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='b4fba856-8b10-4630-89e7-1aef33c527ce')], 'num_planning_cycles': 1, 'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='b4fba856-8b10-4630-89e7-1aef33c527ce')]}
# Agent node output: content='The weather in Bengaluru is few clouds with a temperature of 17 degrees Celsius, feels like 16.82 degrees Celsius, humidity of 79%, and wind speed of 5.14 m/s.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--5b5628a5-52b8-41ee-9b67-7ac389eb0ac7-0' usage_metadata={'input_tokens': 669, 'output_tokens': 48, 'total_tokens': 717, 'input_token_details': {'cache_read': 0}}
# [updates] {'agent': {'messages': [AIMessage(content='The weather in Bengaluru is few clouds with a temperature of 17 degrees Celsius, feels like 16.82 degrees Celsius, humidity of 79%, and wind speed of 5.14 m/s.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--5b5628a5-52b8-41ee-9b67-7ac389eb0ac7-0', usage_metadata={'input_tokens': 669, 'output_tokens': 48, 'total_tokens': 717, 'input_token_details': {'cache_read': 0}})]}}
# [values] {'query': [HumanMessage(content='Will it rain in Bengaluru today?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content='The weather in Bengaluru is few clouds with a temperature of 17 degrees Celsius, feels like 16.82 degrees Celsius, humidity of 79%, and wind speed of 5.14 m/s.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--5b5628a5-52b8-41ee-9b67-7ac389eb0ac7-0', usage_metadata={'input_tokens': 669, 'output_tokens': 48, 'total_tokens': 717, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1, 'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='b4fba856-8b10-4630-89e7-1aef33c527ce')]}
#
# {'query': [HumanMessage(content='Will it rain in Bengaluru today?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content='The weather in Bengaluru is few clouds with a temperature of 17 degrees Celsius, feels like 16.82 degrees Celsius, humidity of 79%, and wind speed of 5.14 m/s.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--5b5628a5-52b8-41ee-9b67-7ac389eb0ac7-0', usage_metadata={'input_tokens': 669, 'output_tokens': 48, 'total_tokens': 717, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1, 'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='b4fba856-8b10-4630-89e7-1aef33c527ce')]}
#
# [SystemMessage(content='\n# IDENTITY AND PURPOSE\n\nYou are ClimaDoc’s Answer Compiler.\nYour sole responsibility is to generate a clear, accurate, and user-friendly final response to the user’s query by using the data returned from executed tools.\n\nYou do NOT plan, decide, or call tools.\nYou ONLY synthesize results that already exist.\n\n# INPUTS YOU WILL RECEIVE\n\n- The original user query\n- Tool outputs (weather data, document retrieval results, or both)\n- Any clarification responses provided by the user\n\n# INSTRUCTIONS\n\n1. **Ground Your Answer in Tool Data**\n   - Use only the information explicitly provided by tool outputs.\n   - Do NOT add external knowledge or assumptions.\n   - Do NOT hallucinate weather conditions, forecasts, or document content.\n\n2. **Answer the User’s Query Directly**\n   - Address exactly what the user asked.\n   - Do not introduce unrelated information, but you can always mention some supporting data.\n   - If the question has multiple parts, answer each clearly.\n\n3. **Synthesize, Don’t Dump**\n   - Summarize relevant tool data into natural language.\n   - Avoid raw JSON, logs, or technical fields unless explicitly requested.\n   - Highlight key points (e.g., temperature, rain likelihood, policy rules).\n\n4. **Handle Multi-Source Data Carefully**\n   - If both weather and document data are provided, clearly distinguish them.\n   - Explain how each source contributes to the final answer.\n\n5. **Be Clear and Actionable**\n   - Use simple, conversational language suitable for a chatbot.\n   - When appropriate, provide practical guidance (e.g., “Carry an umbrella”).\n   - Avoid speculative or advisory language beyond the data provided.\n\n6. **Handle Uncertainty Gracefully**\n   - If the tool data is incomplete or unclear, state the limitation clearly.\n   - Do NOT guess or fabricate missing details.\n\n# RESPONSE STYLE GUIDELINES\n\n- Be concise but complete.\n- Use short paragraphs or bullet points when helpful.\n- Do not mention internal tools, prompts, or agent steps.\n- Do not say “according to the tool” — present the information naturally.\n\n# IMPORTANT RULES\n\n- Never create new facts.\n- Never contradict tool outputs.\n- Never include plans or reasoning steps.\n- Output only the final answer to the user.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='Will it rain in Bengaluru today?', additional_kwargs={}, response_metadata={}), ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='b4fba856-8b10-4630-89e7-1aef33c527ce')]
# Answer Compiler node output: content="Today's forecast for Bengaluru indicates a chance of rain. Consider carrying an umbrella." additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--b7769bc7-549f-4b42-be39-43798f45b6a7-0' usage_metadata={'input_tokens': 510, 'output_tokens': 17, 'total_tokens': 527, 'input_token_details': {'cache_read': 0}}
# [updates] {'answer_compiler': {'messages': [AIMessage(content="Today's forecast for Bengaluru indicates a chance of rain. Consider carrying an umbrella.", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--b7769bc7-549f-4b42-be39-43798f45b6a7-0', usage_metadata={'input_tokens': 510, 'output_tokens': 17, 'total_tokens': 527, 'input_token_details': {'cache_read': 0}})]}}
# [values] {'query': [HumanMessage(content='Will it rain in Bengaluru today?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content="Today's forecast for Bengaluru indicates a chance of rain. Consider carrying an umbrella.", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--b7769bc7-549f-4b42-be39-43798f45b6a7-0', usage_metadata={'input_tokens': 510, 'output_tokens': 17, 'total_tokens': 527, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1, 'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='b4fba856-8b10-4630-89e7-1aef33c527ce')]}
# [updates] {'judge': {'is_good_answer': True}}
# [values] {'query': [HumanMessage(content='Will it rain in Bengaluru today?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content="Today's forecast for Bengaluru indicates a chance of rain. Consider carrying an umbrella.", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--b7769bc7-549f-4b42-be39-43798f45b6a7-0', usage_metadata={'input_tokens': 510, 'output_tokens': 17, 'total_tokens': 527, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1, 'is_good_answer': True, 'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='b4fba856-8b10-4630-89e7-1aef33c527ce')]}
# {'query': [HumanMessage(content='Will it rain in Bengaluru today?', additional_kwargs={}, response_metadata={})],
#  'action': 'weather',
#  'messages': [AIMessage(content="Today's forecast for Bengaluru indicates a chance of rain. Consider carrying an umbrella.", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--b7769bc7-549f-4b42-be39-43798f45b6a7-0', usage_metadata={'input_tokens': 510, 'output_tokens': 17, 'total_tokens': 527, 'input_token_details': {'cache_read': 0}})],
#  'num_planning_cycles': 1,
#  'is_good_answer': True,
#  'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='b4fba856-8b10-4630-89e7-1aef33c527ce')]}

# %%
from workflow import run_climadoc_workflow
query = "What is the wind speed in Bengaluru?"
result = run_climadoc_workflow(query)
result
# Out:
# [values] {'query': [HumanMessage(content='What is the wind speed in Bengaluru?', additional_kwargs={}, response_metadata={})], 'messages': [HumanMessage(content='What is the wind speed in Bengaluru?', additional_kwargs={}, response_metadata={})]}
# Decision making node: {'action': 'weather'}
# [updates] {'decision_making': {'action': 'weather'}}
# [values] {'query': [HumanMessage(content='What is the wind speed in Bengaluru?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [HumanMessage(content='What is the wind speed in Bengaluru?', additional_kwargs={}, response_metadata={})]}
# Planning node output: content='1. **Step 1**: Get the wind speed information for Bengaluru. - Use tool: get_weather_info_by_location' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--3f482f93-6d02-48a8-a249-b71873c536c8-0' usage_metadata={'input_tokens': 545, 'output_tokens': 29, 'total_tokens': 574, 'input_token_details': {'cache_read': 0}}
# [updates] {'planning': {'messages': [AIMessage(content='1. **Step 1**: Get the wind speed information for Bengaluru. - Use tool: get_weather_info_by_location', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--3f482f93-6d02-48a8-a249-b71873c536c8-0', usage_metadata={'input_tokens': 545, 'output_tokens': 29, 'total_tokens': 574, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1}}
# [values] {'query': [HumanMessage(content='What is the wind speed in Bengaluru?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content='1. **Step 1**: Get the wind speed information for Bengaluru. - Use tool: get_weather_info_by_location', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--3f482f93-6d02-48a8-a249-b71873c536c8-0', usage_metadata={'input_tokens': 545, 'output_tokens': 29, 'total_tokens': 574, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1}
# Agent node output: content='' additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--c7596ed8-06cc-413f-b808-d84685c14c73-0' tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': '703c317c-27ca-40fa-a002-4b463168068d', 'type': 'tool_call'}] usage_metadata={'input_tokens': 536, 'output_tokens': 12, 'total_tokens': 548, 'input_token_details': {'cache_read': 0}}
# [updates] {'agent': {'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--c7596ed8-06cc-413f-b808-d84685c14c73-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': '703c317c-27ca-40fa-a002-4b463168068d', 'type': 'tool_call'}], usage_metadata={'input_tokens': 536, 'output_tokens': 12, 'total_tokens': 548, 'input_token_details': {'cache_read': 0}})]}}
# [values] {'query': [HumanMessage(content='What is the wind speed in Bengaluru?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--c7596ed8-06cc-413f-b808-d84685c14c73-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': '703c317c-27ca-40fa-a002-4b463168068d', 'type': 'tool_call'}], usage_metadata={'input_tokens': 536, 'output_tokens': 12, 'total_tokens': 548, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1}
# INFO:root:Cache hit for location: Bengaluru
# INFO:root:Cache hit for weather: Bengaluru
# INFO:root:Cache hit for weather: Bengaluru. Cached time difference is 1277 seconds
# December 15, 2025 11:14 PM IST
# [updates] {'tools': {'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--c7596ed8-06cc-413f-b808-d84685c14c73-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': '703c317c-27ca-40fa-a002-4b463168068d', 'type': 'tool_call'}], usage_metadata={'input_tokens': 536, 'output_tokens': 12, 'total_tokens': 548, 'input_token_details': {'cache_read': 0}}), ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='703c317c-27ca-40fa-a002-4b463168068d')], 'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='703c317c-27ca-40fa-a002-4b463168068d')]}}
# [values] {'query': [HumanMessage(content='What is the wind speed in Bengaluru?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather_info_by_location', 'arguments': '{"city": "Bengaluru"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--c7596ed8-06cc-413f-b808-d84685c14c73-0', tool_calls=[{'name': 'get_weather_info_by_location', 'args': {'city': 'Bengaluru'}, 'id': '703c317c-27ca-40fa-a002-4b463168068d', 'type': 'tool_call'}], usage_metadata={'input_tokens': 536, 'output_tokens': 12, 'total_tokens': 548, 'input_token_details': {'cache_read': 0}}), ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='703c317c-27ca-40fa-a002-4b463168068d')], 'num_planning_cycles': 1, 'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='703c317c-27ca-40fa-a002-4b463168068d')]}
# Agent node output: content='The weather in Bengaluru is few clouds, with a temperature of 17 degrees Celsius, feels like 16.82 degrees Celsius, humidity of 79%, and wind speed of 5.14 m/s.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--870228fa-1e56-4ea1-be13-4eb85463e629-0' usage_metadata={'input_tokens': 669, 'output_tokens': 49, 'total_tokens': 718, 'input_token_details': {'cache_read': 0}}
# [updates] {'agent': {'messages': [AIMessage(content='The weather in Bengaluru is few clouds, with a temperature of 17 degrees Celsius, feels like 16.82 degrees Celsius, humidity of 79%, and wind speed of 5.14 m/s.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--870228fa-1e56-4ea1-be13-4eb85463e629-0', usage_metadata={'input_tokens': 669, 'output_tokens': 49, 'total_tokens': 718, 'input_token_details': {'cache_read': 0}})]}}
# [values] {'query': [HumanMessage(content='What is the wind speed in Bengaluru?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content='The weather in Bengaluru is few clouds, with a temperature of 17 degrees Celsius, feels like 16.82 degrees Celsius, humidity of 79%, and wind speed of 5.14 m/s.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--870228fa-1e56-4ea1-be13-4eb85463e629-0', usage_metadata={'input_tokens': 669, 'output_tokens': 49, 'total_tokens': 718, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1, 'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='703c317c-27ca-40fa-a002-4b463168068d')]}
#
# {'query': [HumanMessage(content='What is the wind speed in Bengaluru?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content='The weather in Bengaluru is few clouds, with a temperature of 17 degrees Celsius, feels like 16.82 degrees Celsius, humidity of 79%, and wind speed of 5.14 m/s.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--870228fa-1e56-4ea1-be13-4eb85463e629-0', usage_metadata={'input_tokens': 669, 'output_tokens': 49, 'total_tokens': 718, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1, 'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='703c317c-27ca-40fa-a002-4b463168068d')]}
#
# [SystemMessage(content='\n# IDENTITY AND PURPOSE\n\nYou are ClimaDoc’s Answer Compiler.\nYour sole responsibility is to generate a clear, accurate, and user-friendly final response to the user’s query by using the data returned from executed tools.\n\nYou do NOT plan, decide, or call tools.\nYou ONLY synthesize results that already exist.\n\n# INPUTS YOU WILL RECEIVE\n\n- The original user query\n- Tool outputs (weather data, document retrieval results, or both)\n- Any clarification responses provided by the user\n\n# INSTRUCTIONS\n\n1. **Ground Your Answer in Tool Data**\n   - Use only the information explicitly provided by tool outputs.\n   - Do NOT add external knowledge or assumptions.\n   - Do NOT hallucinate weather conditions, forecasts, or document content.\n\n2. **Answer the User’s Query Directly**\n   - Address exactly what the user asked.\n   - You can always mention some supporting data.\n   - If the question has multiple parts, answer each clearly.\n\n3. **Synthesize, Don’t Dump**\n   - Summarize relevant tool data into natural language.\n   - Avoid raw JSON, logs, or technical fields unless explicitly requested.\n   - Highlight key points (e.g., temperature, rain likelihood, policy rules).\n\n4. **Handle Multi-Source Data Carefully**\n   - If both weather and document data are provided, clearly distinguish them.\n   - Explain how each source contributes to the final answer.\n\n5. **Be Clear and Actionable**\n   - Use simple, conversational language suitable for a chatbot.\n   - When appropriate, provide practical guidance (e.g., “Carry an umbrella”).\n   - Avoid speculative or advisory language beyond the data provided.\n\n6. **Handle Uncertainty Gracefully**\n   - If the tool data is incomplete or unclear, state the limitation clearly.\n   - Do NOT guess or fabricate missing details.\n\n# RESPONSE STYLE GUIDELINES\n\n- Be concise but complete.\n- Use short paragraphs or bullet points when helpful.\n- Do not mention internal tools, prompts, or agent steps.\n- Do not say “according to the tool” — present the information naturally.\n\n# IMPORTANT RULES\n\n- Never create new facts.\n- Never contradict tool outputs.\n- Never include plans or reasoning steps.\n- Output only the final answer to the user.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the wind speed in Bengaluru?', additional_kwargs={}, response_metadata={}), ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='703c317c-27ca-40fa-a002-4b463168068d')]
# Answer Compiler node output: content='The wind speed in Bengaluru is 9 km/h.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--89eb8e42-5cba-4923-baa1-49361f7703d0-0' usage_metadata={'input_tokens': 504, 'output_tokens': 13, 'total_tokens': 517, 'input_token_details': {'cache_read': 0}}
# [updates] {'answer_compiler': {'messages': [AIMessage(content='The wind speed in Bengaluru is 9 km/h.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--89eb8e42-5cba-4923-baa1-49361f7703d0-0', usage_metadata={'input_tokens': 504, 'output_tokens': 13, 'total_tokens': 517, 'input_token_details': {'cache_read': 0}})]}}
# [values] {'query': [HumanMessage(content='What is the wind speed in Bengaluru?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content='The wind speed in Bengaluru is 9 km/h.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--89eb8e42-5cba-4923-baa1-49361f7703d0-0', usage_metadata={'input_tokens': 504, 'output_tokens': 13, 'total_tokens': 517, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1, 'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='703c317c-27ca-40fa-a002-4b463168068d')]}
# [updates] {'judge': {'is_good_answer': True}}
# [values] {'query': [HumanMessage(content='What is the wind speed in Bengaluru?', additional_kwargs={}, response_metadata={})], 'action': 'weather', 'messages': [AIMessage(content='The wind speed in Bengaluru is 9 km/h.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--89eb8e42-5cba-4923-baa1-49361f7703d0-0', usage_metadata={'input_tokens': 504, 'output_tokens': 13, 'total_tokens': 517, 'input_token_details': {'cache_read': 0}})], 'num_planning_cycles': 1, 'is_good_answer': True, 'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='703c317c-27ca-40fa-a002-4b463168068d')]}
# {'query': [HumanMessage(content='What is the wind speed in Bengaluru?', additional_kwargs={}, response_metadata={})],
#  'action': 'weather',
#  'messages': [AIMessage(content='The wind speed in Bengaluru is 9 km/h.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--89eb8e42-5cba-4923-baa1-49361f7703d0-0', usage_metadata={'input_tokens': 504, 'output_tokens': 13, 'total_tokens': 517, 'input_token_details': {'cache_read': 0}})],
#  'num_planning_cycles': 1,
#  'is_good_answer': True,
#  'tool_responses': [ToolMessage(content='{"location": {"city": "Bengaluru", "lat": 12.9762, "lon": 77.6033}, "weather": {"coord": {"lon": 77.6, "lat": 12.98}, "weather": [{"id": 801, "main": "Clouds", "description": "few clouds", "icon": "02n"}], "base": "stations", "main": {"temp": 17, "feels_like": 16.82, "temp_min": 16.75, "temp_max": 17.45, "pressure": 1016, "humidity": 79, "sea_level": 1016, "grnd_level": 917}, "visibility": 6000, "wind": {"speed": 5.14, "deg": 90}, "clouds": {"all": 19}, "dt": "December 15, 2025 11:14 PM IST", "sys": {"type": 2, "id": 2105374, "country": "IN", "sunrise": "December 15, 2025 06:33 AM IST", "sunset": "December 15, 2025 05:55 PM IST"}, "timezone": 19800, "id": 1277333, "name": "Bengaluru", "cod": 200}}', name='get_weather_info_by_location', tool_call_id='703c317c-27ca-40fa-a002-4b463168068d')]}

# %%
{
    "query": [
        HumanMessage(
            content="Will it rain in Bengaluru today?",
            additional_kwargs={},
            response_metadata={},
        )
    ],
    "action": "weather",
    "messages": [
        AIMessage(
            content="The weather in Bengaluru is clear sky. The temperature is 17.06 degrees Celsius, but it feels like 16.86 degrees Celsius. The humidity is 78%. The wind speed is 5.14 m/s.",
            additional_kwargs={},
            response_metadata={
                "prompt_feedback": {"block_reason": 0, "safety_ratings": []},
                "finish_reason": "STOP",
                "model_name": "gemini-2.0-flash",
                "safety_ratings": [],
            },
            id="run--f1eb05eb-60ef-4838-b9da-bd50734d583d-0",
            usage_metadata={
                "input_tokens": 669,
                "output_tokens": 54,
                "total_tokens": 723,
                "input_token_details": {"cache_read": 0},
            },
        )
    ],
    "num_planning_cycles": 1,
}

# %%
from workflow import run_climadoc_workflow
query = "Hai How are you?"
result = run_climadoc_workflow(query)
result
# Out:
# [values] {'messages': [HumanMessage(content='Hai How are you?', additional_kwargs={}, response_metadata={})]}
# Decision making node: {'action': 'direct', 'messages': [AIMessage(content='I am doing well, thank you. How can I help you today?', additional_kwargs={}, response_metadata={})]}
# [updates] {'decision_making': {'action': 'direct', 'messages': [AIMessage(content='I am doing well, thank you. How can I help you today?', additional_kwargs={}, response_metadata={})]}}
# [values] {'action': 'direct', 'messages': [AIMessage(content='I am doing well, thank you. How can I help you today?', additional_kwargs={}, response_metadata={})]}
# {'action': 'direct',
#  'messages': [AIMessage(content='I am doing well, thank you. How can I help you today?', additional_kwargs={}, response_metadata={})]}
